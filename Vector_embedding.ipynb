# %%
# !pip install gensim

# %% [markdown]
# # Import trained model

# %%
import gensim.downloader as api
model = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %% [markdown]
# # Example of a word as a vector

# %%
# Vector embedding
print(model['computer'])
# Out:
# [ 1.07421875e-01 -2.01171875e-01  1.23046875e-01  2.11914062e-01
#  -9.13085938e-02  2.16796875e-01 -1.31835938e-01  8.30078125e-02
#   2.02148438e-01  4.78515625e-02  3.66210938e-02 -2.45361328e-02
#   2.39257812e-02 -1.60156250e-01 -2.61230469e-02  9.71679688e-02
#  -6.34765625e-02  1.84570312e-01  1.70898438e-01 -1.63085938e-01
#  -1.09375000e-01  1.49414062e-01 -4.65393066e-04  9.61914062e-02
#   1.68945312e-01  2.60925293e-03  8.93554688e-02  6.49414062e-02
#   3.56445312e-02 -6.93359375e-02 -1.46484375e-01 -1.21093750e-01
#  -2.27539062e-01  2.45361328e-02 -1.24511719e-01 -3.18359375e-01
#  -2.20703125e-01  1.30859375e-01  3.66210938e-02 -3.63769531e-02
#  -1.13281250e-01  1.95312500e-01  9.76562500e-02  1.26953125e-01
#   6.59179688e-02  6.93359375e-02  1.02539062e-02  1.75781250e-01
#  -1.68945312e-01  1.21307373e-03 -2.98828125e-01 -1.15234375e-01
#   5.66406250e-02 -1.77734375e-01 -2.08984375e-01  1.76757812e-01
# ...

# %%
print(model['computer'].shape)
# Out:
# (300,)

# %%
print(dir(model))
# Out:
# ['__class__', '__contains__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_adapt_by_suffix', '_load_specials', '_log_evaluate_word_analogies', '_save_specials', '_smart_save', '_upconvert_old_d2vkv', '_upconvert_old_vocab', 'add_lifecycle_event', 'add_vector', 'add_vectors', 'allocate_vecattrs', 'closer_than', 'cosine_similarities', 'distance', 'distances', 'doesnt_match', 'evaluate_word_analogies', 'evaluate_word_pairs', 'expandos', 'fill_norms', 'get_index', 'get_mean_vector', 'get_normed_vectors', 'get_vecattr', 'get_vector', 'has_index_for', 'index2entity', 'index2word', 'index_to_key', 'init_sims', 'intersect_word2vec_format', 'key_to_index
# ...

# %% [markdown]
# # Similar words

# %% [markdown]
# # Aryan + coder - Germany

# %%
# Example of using most_similar
print(model.most_similar(positive=['Aryan', 'coding'], negative=['Germany'], topn=10))
# Out:
# [('coder', 0.3898099958896637), ('Scripting', 0.3810974061489105), ('Devanagari', 0.3748833239078522), ('Perl_scripts', 0.3730379641056061), ('Tcl', 0.3709961771965027), ('Vedic_Sanskrit', 0.36714211106300354), ('refactoring', 0.36696165800094604), ('HTML_Javascript', 0.36376065015792847), ('coders', 0.3637497127056122), ('ASCII_characters', 0.3619810938835144)]

# %% [markdown]
# # Let us check the similarity b/w a few pair of words

# %%
# Example of calculating similarity
print(model.similarity('woman', 'man'))
print(model.similarity('king', 'queen'))
print(model.similarity('uncle', 'aunt'))
print(model.similarity('boy', 'girl'))
print(model.similarity('nephew', 'niece'))
print(model.similarity('paper', 'water'))
# Out:
# 0.76640123
# 0.6510957
# 0.7643474
# 0.8543272
# 0.7594367
# 0.11408084

# %% [markdown]
# # Most similar words

# %%
print(model.most_similar("tower", topn=5))
# Out:
# [('towers', 0.8531750440597534), ('skyscraper', 0.6417425870895386), ('Tower', 0.639177143573761), ('spire', 0.594687819480896), ('responded_Understood_Atlasjet', 0.5931612253189087)]

# %% [markdown]
# # Now let us see the vector similarity

# %%
import numpy as np
# Words to compare
word1 = 'man'
word2 = 'woman'

word3 = 'semiconductor'
word4 = 'earthworm'

word5 = 'nephew'
word6 = 'niece'

# Calculate the vector difference
vector_difference1 = model[word1] - model[word2]
vector_difference2 = model[word3] - model[word4]
vector_difference3 = model[word5] - model[word6]
# print(vector_difference1, vector_difference2, vector_difference3)

# Calculate the magnitude of the vector difference
magnitude_of_difference1 = np.linalg.norm(vector_difference1)
magnitude_of_difference2 = np.linalg.norm(vector_difference2)
magnitude_of_difference3 = np.linalg.norm(vector_difference3)


# Print the magnitude of the difference
print("The magnitude of the difference between '{}' and '{}' is {:.2f}".format(word1, word2, magnitude_of_difference1))
print("The magnitude of the difference between '{}' and '{}' is {:.2f}".format(word3, word4, magnitude_of_difference2))
print("The magnitude of the difference between '{}' and '{}' is {:.2f}".format(word5, word6, magnitude_of_difference3))
# Out:
# [ 8.30078125e-02  2.08007812e-01  1.37695312e-01  2.44140625e-02
#  -2.83203125e-02  6.61621094e-02 -8.39843750e-02 -1.87377930e-02
#   3.17382812e-02 -4.66384888e-02  1.25976562e-01  9.37500000e-02
#  -2.09960938e-02 -2.63671875e-02 -7.49511719e-02 -5.34667969e-02
#   8.98437500e-02  1.12792969e-01 -3.27148438e-02 -7.00683594e-02
#  -1.01806641e-01  4.93927002e-02  8.12988281e-02  1.36718750e-01
#   5.38330078e-02  4.10156250e-02  9.27734375e-02 -3.90625000e-03
#   2.53906250e-02  1.66503906e-01  1.85546875e-02  1.42944336e-01
#   1.61621094e-01  8.48388672e-02  1.95312500e-02  1.30859375e-01
#  -5.85937500e-02 -7.81250000e-02  1.67480469e-01  1.21093750e-01
#   1.88720703e-01 -1.04980469e-02  5.37109375e-02  1.61743164e-02
#   9.27734375e-02 -4.49218750e-02  0.00000000e+00 -2.49023438e-02
#  -2.11181641e-02 -1.14257812e-01 -1.86279297e-01  1.23390198e-01
#   2.44140625e-04 -2.22167969e-01  1.58691406e-01 -1.31835938e-02
# ...
